# %%
import pandas as pd 
import numpy as np 
import random

# %%
data = []

#Generating fake dataset
for i in range(1, 10000):
    traffic_density = random.randrange(0, 100)/100
    avg_speed = random.randrange(1, 100)
    signal_duration = random.choice([90, 60, 120, 45])
    time_of_day = random.choice(["Morning", "Afternoon", "Evening", "Night"])

    data.append({
    "time_of_day": time_of_day,
    "traffic_density": traffic_density,  
    "avg_speed": avg_speed,  
    "signal_duration": signal_duration
    })

#Manipulating Dataset
df = pd.DataFrame(data)

df["time_of_day"] = df["time_of_day"].astype("category").cat.codes

df["avg_speed"] = df["avg_speed"] / 100
df["signal_duration"] = df["signal_duration"] / 120

print(df.head())
# Out:
#    time_of_day  traffic_density  avg_speed  signal_duration
# 0            3             0.14       0.93             0.50
# 1            3             0.42       0.01             0.50
# 2            0             0.34       0.70             0.50
# 3            0             0.18       0.49             0.75
# 4            3             0.46       0.08             0.75

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
X = df[["time_of_day", "traffic_density", "avg_speed"]].values
y = df["signal_duration"].values

#Reshape input for LSTM model
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

#LSTM Model
model = Sequential([
    LSTM(50, activation='relu', return_sequences=True, input_shape=(1, X.shape[2])),
    Dropout(0.2),
    LSTM(50, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=50, batch_size=4)
# Out:
# Epoch 1/50
# c:\Users\gtanu\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0996
# Epoch 2/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0605
# Epoch 3/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0595
# Epoch 4/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0609
# Epoch 5/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0595
# Epoch 6/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0590
# Epoch 7/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0592
# Epoch 8/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0586
# Epoch 9/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0582
# Epoch 10/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0576
# Epoch 11/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0582
# Epoch 12/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0584
# Epoch 13/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0588
# Epoch 14/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0590
# Epoch 15/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0578
# Epoch 16/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0586
# Epoch 17/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0582
# Epoch 18/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0573
# Epoch 19/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0582
# Epoch 20/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0589
# Epoch 21/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0576
# Epoch 22/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0587
# Epoch 23/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0580
# Epoch 24/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0583
# Epoch 25/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0586
# Epoch 26/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0587
# Epoch 27/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0566
# Epoch 28/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0580
# Epoch 29/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0588
# Epoch 30/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0583
# Epoch 31/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0585
# Epoch 32/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0581
# Epoch 33/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0579
# Epoch 34/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0586
# Epoch 35/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0584
# Epoch 36/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0578
# Epoch 37/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0577
# Epoch 38/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0577
# Epoch 39/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0587
# Epoch 40/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0583
# Epoch 41/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0590
# Epoch 42/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0580
# Epoch 43/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0584
# Epoch 44/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0587
# Epoch 45/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0579
# Epoch 46/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0583
# Epoch 47/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0585
# Epoch 48/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0578
# Epoch 49/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0590
# Epoch 50/50
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0584

# %%
#Saving our model
model.save("traffic_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
